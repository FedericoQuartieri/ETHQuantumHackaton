# %%
from compiler import *
# Out:
# d:\Repos\ETHQuantumHackaton\assets\baseline
# → d:\Repos\ETHQuantumHackaton\assets\baseline\0.1.qasm parsed & lowered: Method("0.1")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\0.2.qasm parsed & lowered: Method("0.2")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\0.4.qasm parsed & lowered: Method("0.4")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\1.qasm parsed & lowered: Method("1")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\2.qasm parsed & lowered: Method("2")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\3.qasm parsed & lowered: Method("3")
# → d:\Repos\ETHQuantumHackaton\assets\baseline\4.qasm parsed & lowered: Method("4")
# parallel CZ: 0
# parallel U: 0
# other U: 33
# other CZ: 6

# %%
display(fig)
